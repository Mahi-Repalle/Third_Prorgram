# %%
#Develop the python Shell Script to do the basic data cleanup on child labour and
#child marriage data.xlsx a) check duplicates and missing data b) eliminate
#mismatches c) cleans line breaks, spaces, and special characters.

# %%
import pandas as pd
df=pd.read_csv('Child Labour in India.csv')
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.dtypes
# Out:
# Category of States                          object
# States                                      object
# Agriculture                                float64
# Manufacturing                               object
# Construction                               float64
# Trade Hotels & Restaurants                 float64
# Community, Social and Personal Services    float64
# Others                                     float64
# Total                                      float64
# dtype: object

# %%
df.shape
# Out:
# (26, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Category of States                       25 non-null     object
#  1   States                                   25 non-null     object
#  2   Agriculture                              24 non-null     float64
#  3   Manufacturing                            25 non-null     object
#  4   Construction                             24 non-null     float64
#  5   Trade Hotels & Restaurants               24 non-null     float64
#  6   Community, Social and Personal Services  25 non-null     float64
#  7   Others                                   25 non-null     float64
#  8   Total                                    25 non-null     float64
# dtypes: float64(6), object(3)
# memory usage: 2.0+ KB

# %%
df.describe()
# Out:
#        Agriculture  Construction  Trade Hotels & Restaurants  \
# count    24.000000     24.000000                   24.000000
# mean     65.500000      2.279167                   11.812500
# std      21.490827      2.028274                   11.416476
# min       0.000000      0.000000                    3.300000
# 25%      65.525000      0.375000                    7.075000
# 50%      69.150000      1.850000                    8.550000
# 75%      77.700000      3.300000                   10.300000
# max      87.900000      7.000000                   57.800000
#
#        Community, Social and Personal Services     Others  Total
# count                                25.000000  25.000000   25.0
# mean                                  5.964000   1.224000  100.0
# std                                   6.873129   1.024809    0.0
# min                                   0.000000   0.000000  100.0
# 25%                                   1.300000   0.300000  100.0
# ...

# %%
df.head()
# Out:
#             Category of States          States  Agriculture Manufacturing  \
# 0  Non Special Category states  Andhra Pradesh         69.0           9.7
# 1  Non Special Category states           Assam         69.3           8.4
# 2  Non Special Category states           Bihar         71.8          11.2
# 3  Non Special Category states    Chhattisgarh         87.9           2.4
# 4  Non Special Category states           Delhi          0.0          11.1
#
#    Construction  Trade Hotels & Restaurants  \
# 0           3.2                         9.0
# 1           1.8                         7.8
# 2           0.0                        15.5
# 3           0.9                         7.2
# 4           0.0                        57.8
#
#    Community, Social and Personal Services  Others  Total
# 0                                      7.1     2.0  100.0
# 1                                     11.0     1.8  100.0
# 2                                      1.1     0.5  100.0
# ...

# %%
df.tail()
# Out:
#               Category of States          States  Agriculture Manufacturing  \
# 21   Non Special Category states       All India          NaN           9.7
# 22   Non Special Category states  Andhra Pradesh         69.0           9.7
# 23   Non Special Category states  Andhra Pradesh         69.0           9.7
# 24   Non Special Category states  Andhra Pradesh         69.0           9.7
# 25  Non Special Category states*    Biha      r*         71.8          11.2
#
#     Construction  Trade Hotels & Restaurants  \
# 21           NaN                         NaN
# 22           3.2                         9.0
# 23           3.2                         9.0
# 24           4.0                         8.0
# 25           0.0                        15.5
#
#     Community, Social and Personal Services  Others  Total
# 21                                      7.1     2.0  100.0
# 22                                      7.1     2.0  100.0
# ...

# %%
df.head(2)
# Out:
#             Category of States          States  Agriculture Manufacturing  \
# 0  Non Special Category states  Andhra Pradesh         69.0           9.7
# 1  Non Special Category states           Assam         69.3           8.4
#
#    Construction  Trade Hotels & Restaurants  \
# 0           3.2                         9.0
# 1           1.8                         7.8
#
#    Community, Social and Personal Services  Others  Total
# 0                                      7.1     2.0  100.0
# 1                                     11.0     1.8  100.0

# %%
df.tail(2)
# Out:
#               Category of States          States  Agriculture Manufacturing  \
# 24   Non Special Category states  Andhra Pradesh         69.0           9.7
# 25  Non Special Category states*    Biha      r*         71.8          11.2
#
#     Construction  Trade Hotels & Restaurants  \
# 24           4.0                         8.0
# 25           0.0                        15.5
#
#     Community, Social and Personal Services  Others  Total
# 24                                      7.1     2.0  100.0
# 25                                      1.1     0.5  100.0

# %%
#duplicates  checking

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23     True
# 24    False
# 25    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# 2

# %%
duplicates=df[df.duplicated()]

# %%
duplicates
# Out:
#              Category of States          States  Agriculture Manufacturing  \
# 22  Non Special Category states  Andhra Pradesh         69.0           9.7
# 23  Non Special Category states  Andhra Pradesh         69.0           9.7
#
#     Construction  Trade Hotels & Restaurants  \
# 22           3.2                         9.0
# 23           3.2                         9.0
#
#     Community, Social and Personal Services  Others  Total
# 22                                      7.1     2.0  100.0
# 23                                      7.1     2.0  100.0

# %%
df['States'].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23     True
# 24     True
# 25    False
# Name: States, dtype: bool

# %%
duplicate_states=df[df['States'].duplicated()]

# %%
duplicate_states
# Out:
#              Category of States          States  Agriculture Manufacturing  \
# 22  Non Special Category states  Andhra Pradesh         69.0           9.7
# 23  Non Special Category states  Andhra Pradesh         69.0           9.7
# 24  Non Special Category states  Andhra Pradesh         69.0           9.7
#
#     Construction  Trade Hotels & Restaurants  \
# 22           3.2                         9.0
# 23           3.2                         9.0
# 24           4.0                         8.0
#
#     Community, Social and Personal Services  Others  Total
# 22                                      7.1     2.0  100.0
# 23                                      7.1     2.0  100.0
# 24                                      7.1     2.0  100.0

# %%
df['States'].duplicated().sum()
# Out:
# 3

# %%
#duplicates remove

# %%
df.drop_duplicates()
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df['States'].drop_duplicates()
# Out:
# 0       Andhra Pradesh
# 1                Assam
# 2                Bihar
# 3         Chhattisgarh
# 4                Delhi
# 5              Gujarat
# 6              Haryana
# 7            Jharkhand
# 8            Karnataka
# 9               Kerala
# 10      Madhya Pradesh
# 11         Maharashtra
# 12              Orissa
# 13              Punjab
# 14           Rajasthan
# 15          Tamil Nadu
# 16       Uttar Pradesh
# 17         West Bengal
# 18    Himachal Pradesh
# 19         Uttarakhand
# 20                 NaN
# 21           All India
# 25        Biha      r*
# Name: States, dtype: object

# %%
df['States']
# Out:
# 0       Andhra Pradesh
# 1                Assam
# 2                Bihar
# 3         Chhattisgarh
# 4                Delhi
# 5              Gujarat
# 6              Haryana
# 7            Jharkhand
# 8            Karnataka
# 9               Kerala
# 10      Madhya Pradesh
# 11         Maharashtra
# 12              Orissa
# 13              Punjab
# 14           Rajasthan
# 15          Tamil Nadu
# 16       Uttar Pradesh
# 17         West Bengal
# 18    Himachal Pradesh
# 19         Uttarakhand
# 20                 NaN
# 21           All India
# 22      Andhra Pradesh
# 23      Andhra Pradesh
# 24      Andhra Pradesh
# 25        Biha      r*
# Name: States, dtype: object

# %%
df.drop_duplicates(subset=['Category of States'])
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 18       Special Category States  Himachal Pradesh         87.4             0
# 20                           NaN               NaN          NaN           NaN
# 25  Non Special Category states*      Biha      r*         71.8          11.2
#
#     Construction  Trade Hotels & Restaurants  \
# 0            3.2                         9.0
# 18           0.0                         6.7
# 20           NaN                         NaN
# 25           0.0                        15.5
#
#     Community, Social and Personal Services  Others  Total
# 0                                       7.1     2.0  100.0
# 18                                      4.7     1.2  100.0
# 20                                      NaN     NaN    NaN
# 25                                      1.1     0.5  100.0

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.drop_duplicates(subset=['Category of States'],inplace=True)

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 18       Special Category States  Himachal Pradesh         87.4             0
# 20                           NaN               NaN          NaN           NaN
# 25  Non Special Category states*      Biha      r*         71.8          11.2
#
#     Construction  Trade Hotels & Restaurants  \
# 0            3.2                         9.0
# 18           0.0                         6.7
# 20           NaN                         NaN
# 25           0.0                        15.5
#
#     Community, Social and Personal Services  Others  Total
# 0                                       7.1     2.0  100.0
# 18                                      4.7     1.2  100.0
# 20                                      NaN     NaN    NaN
# 25                                      1.1     0.5  100.0

# %%
#handling null values

# %%
df.isnull()
# Out:
#     Category of States  States  Agriculture  Manufacturing  Construction  \
# 0                False   False        False          False         False
# 1                False   False        False          False         False
# 2                False   False        False          False         False
# 3                False   False        False          False         False
# 4                False   False        False          False         False
# 5                False   False        False          False         False
# 6                False   False        False          False         False
# 7                False   False        False          False         False
# 8                False   False        False          False         False
# 9                False   False        False          False         False
# 10               False   False        False          False         False
# 11               False   False        False          False         False
# ...

# %%
df.isnull().sum()
# Out:
# Category of States                         1
# States                                     1
# Agriculture                                2
# Manufacturing                              1
# Construction                               2
# Trade Hotels & Restaurants                 2
# Community, Social and Personal Services    1
# Others                                     1
# Total                                      1
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 12

# %%
df1=df.fillna(1)

# %%
df1.isnull().sum().sum()
# Out:
# 0

# %%
df.isnull().sum().sum()
# Out:
# 12

# %%
df.fillna({'Agriculture' : '1','Construction' : '2'})
# Out:
#               Category of States            States Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh        69.0           9.7
# 1    Non Special Category states             Assam        69.3           8.4
# 2    Non Special Category states             Bihar        71.8          11.2
# 3    Non Special Category states      Chhattisgarh        87.9           2.4
# 4    Non Special Category states             Delhi         0.0          11.1
# 5    Non Special Category states           Gujarat        76.7           2.6
# 6    Non Special Category states           Haryana        65.6           3.8
# 7    Non Special Category states         Jharkhand        65.3          14.6
# 8    Non Special Category states         Karnataka        82.6           9.3
# 9    Non Special Category states            Kerala        19.2          32.8
# 10   Non Special Category states    Madhya Pradesh        82.9          9. 9
# ...

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.fillna({'Agriculture':'1','Construction':'2'},inplace=True)

# %%
df
# Out:
#               Category of States            States Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh        69.0           9.7
# 1    Non Special Category states             Assam        69.3           8.4
# 2    Non Special Category states             Bihar        71.8          11.2
# 3    Non Special Category states      Chhattisgarh        87.9           2.4
# 4    Non Special Category states             Delhi         0.0          11.1
# 5    Non Special Category states           Gujarat        76.7           2.6
# 6    Non Special Category states           Haryana        65.6           3.8
# 7    Non Special Category states         Jharkhand        65.3          14.6
# 8    Non Special Category states         Karnataka        82.6           9.3
# 9    Non Special Category states            Kerala        19.2          32.8
# 10   Non Special Category states    Madhya Pradesh        82.9          9. 9
# ...

# %%
df.dropna()
# Out:
#               Category of States            States Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh        69.0           9.7
# 1    Non Special Category states             Assam        69.3           8.4
# 2    Non Special Category states             Bihar        71.8          11.2
# 3    Non Special Category states      Chhattisgarh        87.9           2.4
# 4    Non Special Category states             Delhi         0.0          11.1
# 5    Non Special Category states           Gujarat        76.7           2.6
# 6    Non Special Category states           Haryana        65.6           3.8
# 7    Non Special Category states         Jharkhand        65.3          14.6
# 8    Non Special Category states         Karnataka        82.6           9.3
# 9    Non Special Category states            Kerala        19.2          32.8
# 10   Non Special Category states    Madhya Pradesh        82.9          9. 9
# ...

# %%
df
# Out:
#               Category of States            States Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh        69.0           9.7
# 1    Non Special Category states             Assam        69.3           8.4
# 2    Non Special Category states             Bihar        71.8          11.2
# 3    Non Special Category states      Chhattisgarh        87.9           2.4
# 4    Non Special Category states             Delhi         0.0          11.1
# 5    Non Special Category states           Gujarat        76.7           2.6
# 6    Non Special Category states           Haryana        65.6           3.8
# 7    Non Special Category states         Jharkhand        65.3          14.6
# 8    Non Special Category states         Karnataka        82.6           9.3
# 9    Non Special Category states            Kerala        19.2          32.8
# 10   Non Special Category states    Madhya Pradesh        82.9          9. 9
# ...

# %%
df.dropna(how='all')
# Out:
#               Category of States            States Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh        69.0           9.7
# 1    Non Special Category states             Assam        69.3           8.4
# 2    Non Special Category states             Bihar        71.8          11.2
# 3    Non Special Category states      Chhattisgarh        87.9           2.4
# 4    Non Special Category states             Delhi         0.0          11.1
# 5    Non Special Category states           Gujarat        76.7           2.6
# 6    Non Special Category states           Haryana        65.6           3.8
# 7    Non Special Category states         Jharkhand        65.3          14.6
# 8    Non Special Category states         Karnataka        82.6           9.3
# 9    Non Special Category states            Kerala        19.2          32.8
# 10   Non Special Category states    Madhya Pradesh        82.9          9. 9
# ...

# %%
df.dropna(how='any')
# Out:
#               Category of States            States Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh        69.0           9.7
# 1    Non Special Category states             Assam        69.3           8.4
# 2    Non Special Category states             Bihar        71.8          11.2
# 3    Non Special Category states      Chhattisgarh        87.9           2.4
# 4    Non Special Category states             Delhi         0.0          11.1
# 5    Non Special Category states           Gujarat        76.7           2.6
# 6    Non Special Category states           Haryana        65.6           3.8
# 7    Non Special Category states         Jharkhand        65.3          14.6
# 8    Non Special Category states         Karnataka        82.6           9.3
# 9    Non Special Category states            Kerala        19.2          32.8
# 10   Non Special Category states    Madhya Pradesh        82.9          9. 9
# ...

# %%
#eliminate mismatches

# %%
states=df['States']=='Andhra Pradesh'

# %%
states
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22     True
# 23     True
# 24     True
# 25    False
# Name: States, dtype: bool

# %%
states=df[df['States']=='Andhra Pradesh']

# %%
states
# Out:
#              Category of States          States Agriculture Manufacturing  \
# 0   Non Special Category states  Andhra Pradesh        69.0           9.7
# 22  Non Special Category states  Andhra Pradesh        69.0           9.7
# 23  Non Special Category states  Andhra Pradesh        69.0           9.7
# 24  Non Special Category states  Andhra Pradesh        69.0           9.7
#
#    Construction  Trade Hotels & Restaurants  \
# 0           3.2                         9.0
# 22          3.2                         9.0
# 23          3.2                         9.0
# 24          4.0                         8.0
#
#     Community, Social and Personal Services  Others  Total
# 0                                       7.1     2.0  100.0
# 22                                      7.1     2.0  100.0
# 23                                      7.1     2.0  100.0
# 24                                      7.1     2.0  100.0

# %%
non_Andhra=df[df['States']!='Andhra Pradesh']
non_Andhra
# Out:
#               Category of States            States Agriculture Manufacturing  \
# 1    Non Special Category states             Assam        69.3           8.4
# 2    Non Special Category states             Bihar        71.8          11.2
# 3    Non Special Category states      Chhattisgarh        87.9           2.4
# 4    Non Special Category states             Delhi         0.0          11.1
# 5    Non Special Category states           Gujarat        76.7           2.6
# 6    Non Special Category states           Haryana        65.6           3.8
# 7    Non Special Category states         Jharkhand        65.3          14.6
# 8    Non Special Category states         Karnataka        82.6           9.3
# 9    Non Special Category states            Kerala        19.2          32.8
# 10   Non Special Category states    Madhya Pradesh        82.9          9. 9
# 11   Non Special Category states       Maharashtra        82.6           5.3
# ...

# %%
#Handling with spaces,special characters and clean line breaks

# %%
category_of_states=df['Category of States'].replace(r'\W','',regex=True)
category_of_states
# Out:
# 0     NonSpecialCategorystates
# 1     NonSpecialCategorystates
# 2     NonSpecialCategorystates
# 3     NonSpecialCategorystates
# 4     NonSpecialCategorystates
# 5     NonSpecialCategorystates
# 6     NonSpecialCategorystates
# 7     NonSpecialCategorystates
# 8     NonSpecialCategorystates
# 9     NonSpecialCategorystates
# 10    NonSpecialCategorystates
# 11    NonSpecialCategorystates
# 12    NonSpecialCategorystates
# 13    NonSpecialCategorystates
# 14    NonSpecialCategorystates
# 15    NonSpecialCategorystates
# 16    NonSpecialCategorystates
# 17    NonSpecialCategorystates
# 18       SpecialCategoryStates
# 19       SpecialCategoryStates
# 20                         NaN
# 21    NonSpecialCategorystates
# 22    NonSpecialCategorystates
# 23    NonSpecialCategorystates
# 24    NonSpecialCategorystates
# 25    NonSpecialCategorystates
# Name: Category of States, dtype: object

# %%
states=df['States'].replace(r'\W','',regex=True)
states
# Out:
# 0       AndhraPradesh
# 1               Assam
# 2               Bihar
# 3        Chhattisgarh
# 4               Delhi
# 5             Gujarat
# 6             Haryana
# 7           Jharkhand
# 8           Karnataka
# 9              Kerala
# 10      MadhyaPradesh
# 11        Maharashtra
# 12             Orissa
# 13             Punjab
# 14          Rajasthan
# 15          TamilNadu
# 16       UttarPradesh
# 17         WestBengal
# 18    HimachalPradesh
# 19        Uttarakhand
# 20                NaN
# 21           AllIndia
# 22      AndhraPradesh
# 23      AndhraPradesh
# 24      AndhraPradesh
# 25              Bihar
# Name: States, dtype: object

# %%
df
# Out:
#               Category of States            States Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh        69.0           9.7
# 1    Non Special Category states             Assam        69.3           8.4
# 2    Non Special Category states             Bihar        71.8          11.2
# 3    Non Special Category states      Chhattisgarh        87.9           2.4
# 4    Non Special Category states             Delhi         0.0          11.1
# 5    Non Special Category states           Gujarat        76.7           2.6
# 6    Non Special Category states           Haryana        65.6           3.8
# 7    Non Special Category states         Jharkhand        65.3          14.6
# 8    Non Special Category states         Karnataka        82.6           9.3
# 9    Non Special Category states            Kerala        19.2          32.8
# 10   Non Special Category states    Madhya Pradesh        82.9          9. 9
# ...

# %%
for col in df:
    col=df[col].replace(r'\W','',regex=True)
df
# Out:
#           Category of States           States Agriculture Manufacturing  \
# 0   NonSpecialCategorystates    AndhraPradesh        69.0            97
# 1   NonSpecialCategorystates            Assam        69.3            84
# 2   NonSpecialCategorystates            Bihar        71.8           112
# 3   NonSpecialCategorystates     Chhattisgarh        87.9            24
# 4   NonSpecialCategorystates            Delhi         0.0           111
# 5   NonSpecialCategorystates          Gujarat        76.7            26
# 6   NonSpecialCategorystates          Haryana        65.6            38
# 7   NonSpecialCategorystates        Jharkhand        65.3           146
# 8   NonSpecialCategorystates        Karnataka        82.6            93
# 9   NonSpecialCategorystates           Kerala        19.2           328
# 10  NonSpecialCategorystates    MadhyaPradesh        82.9            99
# 11  NonSpecialCategorystates      Maharashtra        82.6            53
# ...

# %%
df1=df.dropna()

# %%
df1
# Out:
#           Category of States           States Agriculture Manufacturing  \
# 0   NonSpecialCategorystates    AndhraPradesh        69.0            97
# 1   NonSpecialCategorystates            Assam        69.3            84
# 2   NonSpecialCategorystates            Bihar        71.8           112
# 3   NonSpecialCategorystates     Chhattisgarh        87.9            24
# 4   NonSpecialCategorystates            Delhi         0.0           111
# 5   NonSpecialCategorystates          Gujarat        76.7            26
# 6   NonSpecialCategorystates          Haryana        65.6            38
# 7   NonSpecialCategorystates        Jharkhand        65.3           146
# 8   NonSpecialCategorystates        Karnataka        82.6            93
# 9   NonSpecialCategorystates           Kerala        19.2           328
# 10  NonSpecialCategorystates    MadhyaPradesh        82.9            99
# 11  NonSpecialCategorystates      Maharashtra        82.6            53
# ...

# %%
df
# Out:
#           Category of States           States Agriculture Manufacturing  \
# 0   NonSpecialCategorystates    AndhraPradesh        69.0            97
# 1   NonSpecialCategorystates            Assam        69.3            84
# 2   NonSpecialCategorystates            Bihar        71.8           112
# 3   NonSpecialCategorystates     Chhattisgarh        87.9            24
# 4   NonSpecialCategorystates            Delhi         0.0           111
# 5   NonSpecialCategorystates          Gujarat        76.7            26
# 6   NonSpecialCategorystates          Haryana        65.6            38
# 7   NonSpecialCategorystates        Jharkhand        65.3           146
# 8   NonSpecialCategorystates        Karnataka        82.6            93
# 9   NonSpecialCategorystates           Kerala        19.2           328
# 10  NonSpecialCategorystates    MadhyaPradesh        82.9            99
# 11  NonSpecialCategorystates      Maharashtra        82.6            53
# ...

# %%
df1
# Out:
#           Category of States           States Agriculture Manufacturing  \
# 0   NonSpecialCategorystates    AndhraPradesh        69.0            97
# 1   NonSpecialCategorystates            Assam        69.3            84
# 2   NonSpecialCategorystates            Bihar        71.8           112
# 3   NonSpecialCategorystates     Chhattisgarh        87.9            24
# 4   NonSpecialCategorystates            Delhi         0.0           111
# 5   NonSpecialCategorystates          Gujarat        76.7            26
# 6   NonSpecialCategorystates          Haryana        65.6            38
# 7   NonSpecialCategorystates        Jharkhand        65.3           146
# 8   NonSpecialCategorystates        Karnataka        82.6            93
# 9   NonSpecialCategorystates           Kerala        19.2           328
# 10  NonSpecialCategorystates    MadhyaPradesh        82.9            99
# 11  NonSpecialCategorystates      Maharashtra        82.6            53
# ...

# %%
print('The no of rows {}''\n' 'The no of columns {}'.format(df.shape[0],df.shape[1]))
# Out:
# The no of rows 26
# The no of columns 9

# %%
df.drop('Total',axis=1)
# Out:
#           Category of States           States Agriculture Manufacturing  \
# 0   NonSpecialCategorystates    AndhraPradesh        69.0            97
# 1   NonSpecialCategorystates            Assam        69.3            84
# 2   NonSpecialCategorystates            Bihar        71.8           112
# 3   NonSpecialCategorystates     Chhattisgarh        87.9            24
# 4   NonSpecialCategorystates            Delhi         0.0           111
# 5   NonSpecialCategorystates          Gujarat        76.7            26
# 6   NonSpecialCategorystates          Haryana        65.6            38
# 7   NonSpecialCategorystates        Jharkhand        65.3           146
# 8   NonSpecialCategorystates        Karnataka        82.6            93
# 9   NonSpecialCategorystates           Kerala        19.2           328
# 10  NonSpecialCategorystates    MadhyaPradesh        82.9            99
# 11  NonSpecialCategorystates      Maharashtra        82.6            53
# ...

# %%
df
# Out:
#           Category of States           States Agriculture Manufacturing  \
# 0   NonSpecialCategorystates    AndhraPradesh        69.0            97
# 1   NonSpecialCategorystates            Assam        69.3            84
# 2   NonSpecialCategorystates            Bihar        71.8           112
# 3   NonSpecialCategorystates     Chhattisgarh        87.9            24
# 4   NonSpecialCategorystates            Delhi         0.0           111
# 5   NonSpecialCategorystates          Gujarat        76.7            26
# 6   NonSpecialCategorystates          Haryana        65.6            38
# 7   NonSpecialCategorystates        Jharkhand        65.3           146
# 8   NonSpecialCategorystates        Karnataka        82.6            93
# 9   NonSpecialCategorystates           Kerala        19.2           328
# 10  NonSpecialCategorystates    MadhyaPradesh        82.9            99
# 11  NonSpecialCategorystates      Maharashtra        82.6            53
# ...

# %%
df.drop('Total',axis=1,inplace=True)

# %%
df
# Out:
#           Category of States           States Agriculture Manufacturing  \
# 0   NonSpecialCategorystates    AndhraPradesh        69.0            97
# 1   NonSpecialCategorystates            Assam        69.3            84
# 2   NonSpecialCategorystates            Bihar        71.8           112
# 3   NonSpecialCategorystates     Chhattisgarh        87.9            24
# 4   NonSpecialCategorystates            Delhi         0.0           111
# 5   NonSpecialCategorystates          Gujarat        76.7            26
# 6   NonSpecialCategorystates          Haryana        65.6            38
# 7   NonSpecialCategorystates        Jharkhand        65.3           146
# 8   NonSpecialCategorystates        Karnataka        82.6            93
# 9   NonSpecialCategorystates           Kerala        19.2           328
# 10  NonSpecialCategorystates    MadhyaPradesh        82.9            99
# 11  NonSpecialCategorystates      Maharashtra        82.6            53
# ...

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.drop(20, axis = 0, inplace = True)

# %%
df
# Out:
#               Category of States            States  Agriculture Manufacturing  \
# 0    Non Special Category states    Andhra Pradesh         69.0           9.7
# 1    Non Special Category states             Assam         69.3           8.4
# 2    Non Special Category states             Bihar         71.8          11.2
# 3    Non Special Category states      Chhattisgarh         87.9           2.4
# 4    Non Special Category states             Delhi          0.0          11.1
# 5    Non Special Category states           Gujarat         76.7           2.6
# 6    Non Special Category states           Haryana         65.6           3.8
# 7    Non Special Category states         Jharkhand         65.3          14.6
# 8    Non Special Category states         Karnataka         82.6           9.3
# 9    Non Special Category states            Kerala         19.2          32.8
# 10   Non Special Category states    Madhya Pradesh         82.9          9. 9
# ...

# %%
df.columns
# Out:
# Index(['Category of States', 'States', 'Agriculture', 'Manufacturing',
#        'Construction', 'Trade Hotels & Restaurants',
#        'Community, Social and Personal Services', 'Others', 'Total'],
#       dtype='object')

# %%
rename_columns=['category' if 'Category of States' in colname else 'Agri' if 'Agriculture' in colname else colname for colname in df.columns]

# %%
rename_columns
# Out:
# ['category',
#  'States',
#  'Agri',
#  'Manufacturing',
#  'Construction',
#  'Trade Hotels & Restaurants',
#  'Community, Social and Personal Services',
#  'Others',
#  'Total']

# %%
df['Category of States']
# Out:
# 0      Non Special Category states
# 1      Non Special Category states
# 2      Non Special Category states
# 3      Non Special Category states
# 4      Non Special Category states
# 5      Non Special Category states
# 6      Non Special Category states
# 7      Non Special Category states
# 8      Non Special Category states
# 9      Non Special Category states
# 10     Non Special Category states
# 11     Non Special Category states
# 12     Non Special Category states
# 13     Non Special Category states
# 14     Non Special Category states
# 15     Non Special Category states
# 16     Non Special Category states
# 17     Non Special Category states
# 18         Special Category States
# 19         Special Category States
# 21     Non Special Category states
# 22     Non Special Category states
# 23     Non Special Category states
# 24     Non Special Category states
# 25    Non Special Category states*
# Name: Category of States, dtype: object

# %%
df['Category of States'].value_counts()
# Out:
# Non Special Category states     22
# Special Category States          2
# Non Special Category states*     1
# Name: Category of States, dtype: int64

# %%
df['Category of States'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Category of States'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='Category of States'>

# %%
df['Category of States'].unique()
# Out:
# array(['Non Special Category states', 'Special Category States',
#        'Non Special Category states*'], dtype=object)

# %%
df['Category of States'].nunique()
# Out:
# 3

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
num_cols = np.array([col for col in df.columns if df[col].dtype == 'float64'])
num_cols
# Out:
# array(['Agriculture', 'Construction', 'Trade Hotels & Restaurants',
#        'Community, Social and Personal Services', 'Others', 'Total'],
#       dtype='<U39')

# %%
fig, ax = plt.subplots(nrows = len(num_cols), figsize = (25, 35))
for col in range(len(num_cols)):
    dat = df.sort_values(by = num_cols[col], ascending = False)
    sns.barplot(x = 'States', y = num_cols[col], data = dat, ax = ax[col])
    plt.setp(ax[col].get_xticklabels(), rotation = 'vertical')

# %%
fig, ax = plt.subplots(3,2, figsize = (45, 24))
for x in range(3):
    for y in range(2):
        sns.barplot(x = 'States', y = num_cols.reshape(3,2)[x][y], data = df, ax = ax[x][y])
        plt.setp(ax[x][y].get_xticklabels(), rotation = 'vertical', fontsize=11)
        ax[x][y].set_ylabel(num_cols.reshape(3, 2)[x][y], fontsize = 15)
